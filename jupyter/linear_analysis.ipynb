# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000]
time = [381.46, 397.63, 422.70, 454.22, 518.88, 687.08, 998.88, 1556.51]
plt.plot(x, time)

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time = [380.72, 385.24, 393.08, 406.92, 428.89, 498.63, 647.53, 848.02, 1441.07, 1846.85]
plt.plot(x, time)

# %%
x[0:4]
# Out:
# [1, 20, 50, 100]

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000]
time = [380.72, 385.24, 393.08, 406.92, 428.89, 498.63, 647.53, 848.02, 1441.07, 1846.85, 3618.83]

# %%
m,b = np.polyfit(x, time, 1)

# %%
m
# Out:
# 0.15853385360320477

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time = [380, 391, 384, 389, 397, 422, 467, 560.07, 741, 1040.68]
m,b = np.polyfit(x, time, 1)
print(m)
plt.plot(x, time)
# Out:
# 0.0664899676372

# %%
sum(time)
# Out:
# 5171.75

# %%
x=[1, 20, 50, 100, 200, 500, 1000]
time=[380, 385, 407, 421, 442, 528, 620]
m,b = np.polyfit(x, time, 1)
print(m)
plt.plot(x, time)
# Out:
# 0.239358887165

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[380.35, 383.64, 397.40, 455.21, 433.83, 523.43, 597.06, 808.96, 1362.60, 1639.01]
m,b = np.polyfit(x, time, 1)
print(m)
plt.plot(x, time)
# Out:
# 0.133752700198

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time1=[380.69, 381.16, 382.49, 384.09, 388.40, 399.17, 421.59, 467.52, 509.35, 579.11]
m,b = np.polyfit(x, time1, 1)
print(m)
plt.plot(x, time1)
# Out:
# 0.0204335946981

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time2=[55.65, 54.08, 67.87, 73.60, 73.77, 74.05, 103.35, 154.67, 292.55, 633.10]
m,b = np.polyfit(x, time2, 1)
print(m)
plt.plot(x, time2)
# Out:
# 0.0557961271258

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time3=[120.75, 276.06, 375.30, 384.35, 333.87, 384.65, 543.30, 780.59, 1143.37, 1182.44]
m,b = np.polyfit(x, time, 1)
print(m)
plt.plot(x, time3)
# Out:
# 0.100769907337

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000]
time3=[108.80, 362.50, 415.48, 410.86, 296.44, 311.27, 423.30, 596.20, 860.72]
m,b = np.polyfit(x, time3, 1)
print(m)
plt.plot(x, time3)
# Out:
# 0.114667919381

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000]
time3=[123.81, 132.00, 143.39, 158.96, 191.13, 309.77, 449.83, 607.29, 881.51]
m,b = np.polyfit(x, time3, 1)
print(m)
plt.plot(x, time3)
# Out:
# 0.154746006457

# %% [markdown]
# # Mira Linear Read

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[50.33, 61.63, 68.95, 78.05, 94.64, 154.65, 222.83, 326.40, 482.10, 530.64]
m,b = np.polyfit(x, time, 1)
print(m)
plt.plot(x, time)
# Out:
# 0.0506340005492

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000][:-3]
time=[4.41, 4.66, 5.76, 6.73, 13.31, 29.66, 58.09, 115.23, 286.88, 565.72, 1075.88, 2424.89][:-3]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0567878281475
# 2.3294640559

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000][:-3]
time=[16.13, 16.60, 17.49, 19.75, 21.20, 29.97, 58.84, 116.52, 289.22, 574.63, 1133.27, 2824.08][:-3]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0548761582838
# 10.990399985

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000][:-1]
time=[15.77, 17.02, 18.15, 20.93, 24.34, 57.57, 106.72, 193.89, 486.03, 1017.62][:-1]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0943788726579
# 11.4650022946

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000][5:-1]
time=[5.48, 10.25, 17.02, 21.61, 30.53, 30.19, 53.35, 85.67, 188.91, 267.70][5:-1]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0347347692308
# 15.7186153846

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[2.31, 2.04, 5.46, 7.35, 13.13, 38.48, 16.73, 20.79, 59.91, 175.52]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0157471187133
# 4.45561227608

# %%
x=[1000, 2000, 5000, 10000]
time=[16.73, 20.79, 59.91, 175.52]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0180568367347
# -13.0182653061

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000][6:]
time=[14.97, 15.14, 15.10, 15.12, 15.26, 15.18, 21.02, 40.88, 101.22, 201.91, 403.21][6:]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0201225373134
# 0.71671641791

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000][:-1]
time=[14.68, 14.60, 14.84, 14.71, 14.66, 14.78, 14.93, 15.16, 15.97, 17.38, 20.10, 28.22][:-1]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.000271316429998
# 14.6603326409

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000][:-2]
time=[15.80, 24.87, 24.66, 33.27, 50.22, 96.52, 148.20, 269.52, 703.56, 1301.22]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.129326755797
# 22.7314791361

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000][:-2]
time=[16.37, 19.22, 22.70, 27.31, 50.32, 90.87, 121.41, 165.28, 440.86, 894.92]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0863382951157
# 21.9970032872

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000][:-3]
time=[15.21, 15.16, 15.21, 21.39, 41.19, 100.84, 200.84, 400.90, 1001.31]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.19875589273
# 5.43183062162

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000][:-3]
time=[5.99, 5.66, 5.30, 5.57, 9.34, 20.73, 40.74, 80.84, 201.29]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0395177757971
# 2.7664234338

# %%
x = [500, 1000, 2000, 5000, 10000, 20000, 50000]
time=[14.92, 15.37, 16.03, 18.28, 21.88, 29.22, 36.43]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.000443471355432
# 16.1261121492

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[74.85, 75.58, 77.01, 79.32, 83.98, 96.41, 110.27, 136.97, 289.44, 576.36]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0491455357881
# 67.2764594142

# %% [markdown]
# ## p=1

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[15.89, 16.59, 17.95, 19.88, 21.16, 29.90, 58.56, 116.14, 288.97, 574.35]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0561161652517
# 10.0421845535

# %% [markdown]
# ## p=2

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[8.86, 9.19, 10.43, 11.86, 14.52, 29.81, 58.45, 115.12, 286.79, 569.74]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0563521567281
# 5.13484503836

# %% [markdown]
# ## p=4

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[5.33, 6.33, 7.59, 10.35, 14.91, 29.77, 58.22, 115.85, 288.78, 571.72]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0567941808791
# 3.70870126306

# %% [markdown]
# ## p=8

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[5.85, 7.00, 7.54, 9.88, 14.56, 29.71, 59.31, 116.75, 291.13, 572.88]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0569550689646
# 3.98108935683

# %% [markdown]
# ## cc=2

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000][1:]
time=[16.24, 8.74, 9.21, 10.33, 11.06, 15.37, 28.15, 55.33, 129.25, 255.13][1:]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0248214677734
# 6.02098923504

# %% [markdown]
# ## cc=4

# %%
x = [20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[5.46, 5.75, 6.10, 6.65, 8.58, 14.73, 29.23, 65.71, 127.37]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0123083763506
# 4.14677091828

# %% [markdown]
# ## cc=8

# %%
x = [20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[5.54, 5.41, 5.57, 5.88, 5.36, 7.99, 13.62, 33.39, 63.73]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.00591955811626
# 3.8653264829

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[4.97, 15.28, 19.33, 33.60, 35.69, 42.31, 66.48, 134.90, 307.39, 548.21]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0539472364264
# 19.0121701397

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[4.71, 11.23, 18.93, 29.89, 39.55, 52.77, 96.60, 131.70, 313.17, 551.74]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.054094517083
# 22.9472368127

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[16.90, 18.37, 32.69, 46.61, 54.77, 100.71, 162.00, 296.78, 771.61, 1774.39]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.17156321246
# 3.72606176708

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[5.36, 11.56, 27.00, 22.99, 40.17, 41.24, 61.12, 120.10, 315.31, 600.56]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0587782436429
# 13.6205764216

# %%
x = [1, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
time=[16.45, 47.97, 53.73, 19.23, 58.73, 56.46, 22.92, 76.84, 211.39, 292.22]
m,b = np.polyfit(x, time, 1)
print(m)
print(b)
plt.plot(x, time)
# Out:
# 0.0273104629168
# 34.0564254296
