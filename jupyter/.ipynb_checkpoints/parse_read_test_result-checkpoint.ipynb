# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime
import pytz

# %%
def convert_datetime_timezone(dt, tz1, tz2):
    tz1 = pytz.timezone(tz1)
    tz2 = pytz.timezone(tz2)

    dt = datetime.datetime.strptime(dt,"%Y-%m-%d %H.%M.%S")
    dt = tz1.localize(dt)
    dt = dt.astimezone(tz2)
    dt = dt.strftime("%Y-%m-%d %H:%M:%S")

    return dt

# %%
#path = "/global/cscratch1/sd/yuanlai/gf_test/read_test_results/vary_cc_result/06.28-20.25.52_night_posix.txt"
path = "/global/cscratch1/sd/yuanlai/gf_test/l2g_test_results/vary_cc_result/07.04-19.52.08_mpi.txt"

# %%
ccMax = 96
totalSize = 2**40
ccList = range(1, ccMax + 1)

# %%
tr = []
timeStamps = []
with open(path, 'r') as fp:
        for cc in range(1, ccMax + 1):
                timestamp = fp.readline().rstrip('\n')
                if int(timestamp.split('.')[0]) >= 19:
                    timestamp = '2018-7-4 ' + timestamp
                else:
                    timestamp = '2018-7-5 ' + timestamp
                timeStamps.append(timestamp)
                timestr = fp.readline().rstrip('\n')
                #print timestr
                try:
                        time = float(timestr)
                except:
                        break
                speed = totalSize / time
                speed = float("%.2f" % (speed / (2**30)))
                tr.append(speed)
                print("cc=" + str(cc) + ":      " + "transfer rate=" + str(speed) + "GB/s")
# Out:
# cc=1:      transfer rate=0.76GB/s
# cc=2:      transfer rate=1.46GB/s
# cc=3:      transfer rate=1.9GB/s
# cc=4:      transfer rate=2.88GB/s
# cc=5:      transfer rate=3.07GB/s
# cc=6:      transfer rate=3.7GB/s
# cc=7:      transfer rate=4.42GB/s
# cc=8:      transfer rate=4.66GB/s
# cc=9:      transfer rate=6.11GB/s
# cc=10:      transfer rate=6.39GB/s
# cc=11:      transfer rate=7.89GB/s
# cc=12:      transfer rate=8.4GB/s
# cc=13:      transfer rate=8.75GB/s
# cc=14:      transfer rate=7.76GB/s
# cc=15:      transfer rate=8.64GB/s
# cc=16:      transfer rate=9.09GB/s
# cc=17:      transfer rate=9.31GB/s
# cc=18:      transfer rate=7.76GB/s
# cc=19:      transfer rate=9.73GB/s
# cc=20:      transfer rate=8.73GB/s
# cc=21:      transfer rate=11.01GB/s
# cc=22:      transfer rate=10.0GB/s
# cc=23:      transfer rate=10.87GB/s
# cc=24:      transfer rate=11.25GB/s
# cc=25:      transfer rate=11.87GB/s
# cc=26:      transfer rate=11.49GB/s
# cc=27:      transfer rate=11.36GB/s
# cc=28:      transfer rate=12.79GB/s
# cc=29:      transfer rate=12.03GB/s
# cc=30:      transfer rate=12.09GB/s
# cc=31:      transfer rate=12.54GB/s
# cc=32:      transfer rate=13.27GB/s
# cc=33:      transfer rate=5.22GB/s
# cc=34:      transfer rate=4.6GB/s
# cc=35:      transfer rate=14.85GB/s
# cc=36:      transfer rate=10.24GB/s
# cc=37:      transfer rate=4.86GB/s
# cc=38:      transfer rate=6.22GB/s
# cc=39:      transfer rate=4.56GB/s
# cc=40:      transfer rate=4.36GB/s
# cc=41:      transfer rate=6.29GB/s
# cc=42:      transfer rate=17.22GB/s
# cc=43:      transfer rate=3.58GB/s
# cc=44:      transfer rate=3.01GB/s
# cc=45:      transfer rate=3.38GB/s
# cc=46:      transfer rate=8.53GB/s
# cc=47:      transfer rate=6.45GB/s
# cc=48:      transfer rate=6.36GB/s
# cc=49:      transfer rate=3.14GB/s
# cc=50:      transfer rate=4.42GB/s
# cc=51:      transfer rate=1.84GB/s
# cc=52:      transfer rate=3.18GB/s
# cc=53:      transfer rate=1.97GB/s
# cc=54:      transfer rate=2.99GB/s
# cc=55:      transfer rate=2.8GB/s
# cc=56:      transfer rate=3.68GB/s
# cc=57:      transfer rate=7.24GB/s
# cc=58:      transfer rate=4.28GB/s
# cc=59:      transfer rate=3.06GB/s
# cc=60:      transfer rate=3.42GB/s
# cc=61:      transfer rate=3.65GB/s
# cc=62:      transfer rate=2.71GB/s
# cc=63:      transfer rate=4.9GB/s
# cc=64:      transfer rate=5.4GB/s
# cc=65:      transfer rate=6.95GB/s
# cc=66:      transfer rate=2.63GB/s
# cc=67:      transfer rate=4.0GB/s
# cc=68:      transfer rate=1.85GB/s
# cc=69:      transfer rate=3.42GB/s
# cc=70:      transfer rate=5.03GB/s
# cc=71:      transfer rate=2.68GB/s
# cc=72:      transfer rate=2.91GB/s
# cc=73:      transfer rate=3.31GB/s
# cc=74:      transfer rate=4.67GB/s
# cc=75:      transfer rate=2.87GB/s
# cc=76:      transfer rate=4.38GB/s
# cc=77:      transfer rate=5.78GB/s
# cc=78:      transfer rate=3.47GB/s
# cc=79:      transfer rate=2.28GB/s
# cc=80:      transfer rate=5.05GB/s
# cc=81:      transfer rate=5.52GB/s
# cc=82:      transfer rate=2.36GB/s
# cc=83:      transfer rate=3.38GB/s
# cc=84:      transfer rate=2.61GB/s
# cc=85:      transfer rate=3.35GB/s
# cc=86:      transfer rate=2.96GB/s
# cc=87:      transfer rate=3.71GB/s
# cc=88:      transfer rate=2.64GB/s
# cc=89:      transfer rate=4.27GB/s
# cc=90:      transfer rate=2.99GB/s
# cc=91:      transfer rate=2.39GB/s
# cc=92:      transfer rate=8.97GB/s
# cc=93:      transfer rate=5.2GB/s
# cc=94:      transfer rate=2.57GB/s
# cc=95:      transfer rate=2.63GB/s
# cc=96:      transfer rate=4.96GB/s

# %%
plt.plot(ccList, tr)
plt.xlabel("cc")
plt.ylabel("GB/s")
ax = plt.axes()        
ax.yaxis.grid()
plt.show()
trMax = max(tr)
trMaxIdx = tr.index(trMax) + 1
print("Highest transfer rate achieved is " + str(max(tr)) + "GB/s, when cc is " + str(trMaxIdx))
# Out:
# Highest transfer rate achieved is 17.22GB/s, when cc is 42

# %%
timeStamps
# Out:
# ['2018-7-4 19.52.13',
#  '2018-7-4 20.14.37',
#  '2018-7-4 20.26.16',
#  '2018-7-4 20.35.15',
#  '2018-7-4 20.41.11',
#  '2018-7-4 20.46.44',
#  '2018-7-4 20.51.21',
#  '2018-7-4 20.55.12',
#  '2018-7-4 20.58.53',
#  '2018-7-4 21.01.41',
#  '2018-7-4 21.04.22',
#  '2018-7-4 21.06.31',
#  '2018-7-4 21.08.33',
#  '2018-7-4 21.10.30',
#  '2018-7-4 21.12.42',
#  '2018-7-4 21.14.41',
#  '2018-7-4 21.16.33',
#  '2018-7-4 21.18.24',
#  '2018-7-4 21.20.36',
#  '2018-7-4 21.22.21',
#  '2018-7-4 21.24.18',
#  '2018-7-4 21.25.51',
#  '2018-7-4 21.27.34',
#  '2018-7-4 21.29.08',
#  '2018-7-4 21.30.39',
#  '2018-7-4 21.32.05',
#  '2018-7-4 21.33.34',
#  '2018-7-4 21.35.05',
#  '2018-7-4 21.36.25',
#  '2018-7-4 21.37.50',
#  '2018-7-4 21.39.14',
#  '2018-7-4 21.40.36',
#  '2018-7-4 21.41.53',
#  '2018-7-4 21.45.10',
#  '2018-7-4 21.48.58',
#  '2018-7-4 21.50.07',
#  '2018-7-4 21.51.47',
#  '2018-7-4 21.55.18',
#  '2018-7-4 21.58.02',
#  '2018-7-4 22.01.47',
#  '2018-7-4 22.05.43',
#  '2018-7-4 22.08.26',
#  '2018-7-4 22.09.26',
#  '2018-7-4 22.14.13',
#  '2018-7-4 22.19.54',
#  '2018-7-4 22.24.57',
#  '2018-7-4 22.26.57',
#  '2018-7-4 22.29.36',
#  '2018-7-4 22.32.17',
#  '2018-7-4 22.37.46',
#  '2018-7-4 22.41.38',
#  '2018-7-4 22.50.55',
#  '2018-7-4 22.56.17',
#  '2018-7-4 23.04.58',
#  '2018-7-4 23.10.40',
#  '2018-7-4 23.16.46',
#  '2018-7-4 23.21.25',
#  '2018-7-4 23.23.46',
#  '2018-7-4 23.27.45',
#  '2018-7-4 23.33.22',
#  '2018-7-4 23.38.21',
#  '2018-7-4 23.43.02',
#  '2018-7-4 23.49.20',
#  '2018-7-4 23.52.50',
#  '2018-7-4 23.56.01',
#  '2018-7-4 23.58.38',
#  '2018-7-5 00.05.08',
#  '2018-7-5 00.09.24',
#  '2018-7-5 00.18.38',
#  '2018-7-5 00.23.53',
#  '2018-7-5 00.27.17',
#  '2018-7-5 00.33.39',
#  '2018-7-5 00.39.53',
#  '2018-7-5 00.45.02',
#  '2018-7-5 00.48.42',
#  '2018-7-5 00.54.39',
#  '2018-7-5 00.58.34',
#  '2018-7-5 01.01.31',
#  '2018-7-5 01.06.27',
#  '2018-7-5 01.14.06',
#  '2018-7-5 01.17.36',
#  '2018-7-5 01.20.42',
#  '2018-7-5 01.27.56',
#  '2018-7-5 01.33.04',
#  '2018-7-5 01.39.36',
#  '2018-7-5 01.44.42',
#  '2018-7-5 01.50.29',
#  '2018-7-5 01.55.17',
#  '2018-7-5 02.01.45',
#  '2018-7-5 02.05.46',
#  '2018-7-5 02.11.28',
#  '2018-7-5 02.18.38',
#  '2018-7-5 02.20.44',
#  '2018-7-5 02.24.01',
#  '2018-7-5 02.30.41',
#  '2018-7-5 02.37.10']

# %%
timeStampsUTC = [convert_datetime_timezone(timeStamp, 'America/Los_Angeles', 'UTC') for timeStamp in timeStamps]

# %%
timeStampsUTC
# Out:
# ['2018-07-05 02:52:13',
#  '2018-07-05 03:14:37',
#  '2018-07-05 03:26:16',
#  '2018-07-05 03:35:15',
#  '2018-07-05 03:41:11',
#  '2018-07-05 03:46:44',
#  '2018-07-05 03:51:21',
#  '2018-07-05 03:55:12',
#  '2018-07-05 03:58:53',
#  '2018-07-05 04:01:41',
#  '2018-07-05 04:04:22',
#  '2018-07-05 04:06:31',
#  '2018-07-05 04:08:33',
#  '2018-07-05 04:10:30',
#  '2018-07-05 04:12:42',
#  '2018-07-05 04:14:41',
#  '2018-07-05 04:16:33',
#  '2018-07-05 04:18:24',
#  '2018-07-05 04:20:36',
#  '2018-07-05 04:22:21',
#  '2018-07-05 04:24:18',
#  '2018-07-05 04:25:51',
#  '2018-07-05 04:27:34',
#  '2018-07-05 04:29:08',
#  '2018-07-05 04:30:39',
#  '2018-07-05 04:32:05',
#  '2018-07-05 04:33:34',
#  '2018-07-05 04:35:05',
#  '2018-07-05 04:36:25',
#  '2018-07-05 04:37:50',
#  '2018-07-05 04:39:14',
#  '2018-07-05 04:40:36',
#  '2018-07-05 04:41:53',
#  '2018-07-05 04:45:10',
#  '2018-07-05 04:48:58',
#  '2018-07-05 04:50:07',
#  '2018-07-05 04:51:47',
#  '2018-07-05 04:55:18',
#  '2018-07-05 04:58:02',
#  '2018-07-05 05:01:47',
#  '2018-07-05 05:05:43',
#  '2018-07-05 05:08:26',
#  '2018-07-05 05:09:26',
#  '2018-07-05 05:14:13',
#  '2018-07-05 05:19:54',
#  '2018-07-05 05:24:57',
#  '2018-07-05 05:26:57',
#  '2018-07-05 05:29:36',
#  '2018-07-05 05:32:17',
#  '2018-07-05 05:37:46',
#  '2018-07-05 05:41:38',
#  '2018-07-05 05:50:55',
#  '2018-07-05 05:56:17',
#  '2018-07-05 06:04:58',
#  '2018-07-05 06:10:40',
#  '2018-07-05 06:16:46',
#  '2018-07-05 06:21:25',
#  '2018-07-05 06:23:46',
#  '2018-07-05 06:27:45',
#  '2018-07-05 06:33:22',
#  '2018-07-05 06:38:21',
#  '2018-07-05 06:43:02',
#  '2018-07-05 06:49:20',
#  '2018-07-05 06:52:50',
#  '2018-07-05 06:56:01',
#  '2018-07-05 06:58:38',
#  '2018-07-05 07:05:08',
#  '2018-07-05 07:09:24',
#  '2018-07-05 07:18:38',
#  '2018-07-05 07:23:53',
#  '2018-07-05 07:27:17',
#  '2018-07-05 07:33:39',
#  '2018-07-05 07:39:53',
#  '2018-07-05 07:45:02',
#  '2018-07-05 07:48:42',
#  '2018-07-05 07:54:39',
#  '2018-07-05 07:58:34',
#  '2018-07-05 08:01:31',
#  '2018-07-05 08:06:27',
#  '2018-07-05 08:14:06',
#  '2018-07-05 08:17:36',
#  '2018-07-05 08:20:42',
#  '2018-07-05 08:27:56',
#  '2018-07-05 08:33:04',
#  '2018-07-05 08:39:36',
#  '2018-07-05 08:44:42',
#  '2018-07-05 08:50:29',
#  '2018-07-05 08:55:17',
#  '2018-07-05 09:01:45',
#  '2018-07-05 09:05:46',
#  '2018-07-05 09:11:28',
#  '2018-07-05 09:18:38',
#  '2018-07-05 09:20:44',
#  '2018-07-05 09:24:01',
#  '2018-07-05 09:30:41',
#  '2018-07-05 09:37:10']

# %%
path = "/global/cscratch1/sd/yuanlai/gf_test/dtn_cpu_usage/dtn01.csv"
headers = ('cpu_usr', 'cpu_sys', 'cpu_idle', 'cpu_wait', 'cpu_hiq', 'cpu_siq', 'drd', 'dwr', \
               'net_recv', 'net_send', 'page_in', 'page_out', 'intr', 'csw', 'timestamp')

# %%
_df = pd.read_csv(path, skiprows=7, names=headers, header=None)
_df['timestamp'] = _df.timestamp.apply(pd.datetime.utcfromtimestamp)
_df.index = _df['timestamp']
del _df['timestamp']
